# %% [markdown]
# # loading and exploring cpnet

# %% [markdown]
# ## loading graph

# %%
# !head data/conceptnet-en.csv
# !wc -l data/conceptnet-en.csv
# Out:
# Antonym	0	1	1.0
# Antonym	12_hour_clock	24_hour_clock	1.0
# Antonym	24_hour_clock	12_hour_clock	1.0
# Antonym	5	3	1.0
# Antonym	a.c	d.c	1.0
# Antonym	a.m	afternoon	1.0
# Antonym	a.m	p.m	3.464
# Antonym	a.m	pm	1.0
# Antonym	ab_extra	ab_intra	1.0
# Antonym	ab_intra	ab_extra	1.0
# 3423004 data/conceptnet-en.csv

# %%
# !cat data/conceptnet-en.csv | grep soccer
# Out:
# AtLocation	advertisements	soccer_game	1.0
# AtLocation	angry_mothers	soccer_game	1.0
# AtLocation	ball	soccer_field	2.0
# AtLocation	ball	soccer_game	2.0
# AtLocation	balls	soccer_game	3.464
# AtLocation	beer	soccer_game	1.0
# AtLocation	black_and_white_soccer_ball	soccer_game	1.0
# AtLocation	bleachers	soccer_game	1.0
# AtLocation	blood	soccer_game	1.0
# AtLocation	cheering_parents	soccer_game	1.0
# AtLocation	children	soccer_game	1.0
# AtLocation	coach	soccer_game	1.0
# AtLocation	drunken_fans	soccer_game	1.0
# AtLocation	fans	soccer_game	2.0
# AtLocation	field	soccer_game	1.0
# AtLocation	football_players	soccer_game	1.0
# AtLocation	goal	soccer_game	1.0
# AtLocation	goalie	soccer_game	1.0
# AtLocation	goalies	soccer_game	2.0
# AtLocation	grass	soccer_game	1.0
# AtLocation	hot_dog	soccer_game	1.0
# AtLocation	keeper	soccer_game	1.0
# AtLocation	knee_pads	soccer_game	1.0
# AtLocation	net	soccer_game	1.0
# AtLocation	parent	soccer_game	2.0
# AtLocation	parents	soccer_game	1.0
# AtLocation	people_wearing_socks	soccer_game	1.0
# AtLocation	players	soccer_game	1.0
# AtLocation	popcorn	soccer_game	1.0
# AtLocation	referee	soccer_game	1.0
# AtLocation	referees	soccer_game	2.0
# AtLocation	shin_gaurds	soccer_game	1.0
# AtLocation	shin_guard	soccer_game	1.0
# AtLocation	shorts	soccer_game	1.0
# AtLocation	soccar_ball	soccer_game	1.0
# AtLocation	soccer_ball	field	1.0
# AtLocation	soccer_ball	lawn	2.0
# AtLocation	soccer_balls	soccer_game	2.828
# AtLocation	soccer_balls	sporting_goods_store	1.0
# AtLocation	soccer_fans	soccer_game	1.0
# AtLocation	soccer_field	countryside	1.0
# AtLocation	soccer_field	mexico	1.0
# AtLocation	soccer_field	midst_of_much_fucking_chaos	1.0
# AtLocation	soccer_field	near	1.0
# AtLocation	soccer_field	open_place	1.0
# AtLocation	soccer_field	outside	1.0
# AtLocation	soccer_field	park	2.828
# AtLocation	soccer_field	playground	1.0
# AtLocation	soccer_field	school	1.0
# AtLocation	soccer_field	school_playing_field	1.0
# AtLocation	soccer_field	school_yard	1.0
# AtLocation	soccer_field	soccer_stadium	1.0
# AtLocation	soccer_field	stadium	1.0
# AtLocation	soccer_field	town	2.0
# AtLocation	soccer_mom	soccer_game	1.0
# AtLocation	soccer_moms	soccer_game	2.828
# AtLocation	soccer_net	soccer_game	2.0
# AtLocation	soccer_player	soccer_field	1.0
# AtLocation	soccer_socks	sporting_goods_store	1.0
# AtLocation	soccer_team	field	1.0
# AtLocation	soccerball	lawn	1.0
# AtLocation	soccerball	soccer_game	1.0
# AtLocation	spectators	soccer_game	2.0
# AtLocation	team	soccer_game	2.828
# AtLocation	team_uniforms	soccer_game	1.0
# AtLocation	trash	soccer_game	1.0
# AtLocation	two_teams	soccer_game	1.0
# AtLocation	violent_fans	soccer_game	2.0
# AtLocation	whistle	soccer_game	1.0
# AtLocation	yelling	soccer_game	1.0
# CapableOf	athelete	play_soccer	1.0
# CapableOf	families	attend_soccer_games	1.0
# CapableOf	head	collide_while_playing_soccer	1.0
# CapableOf	heading_soccer_ball	cause_brain_damage	1.0
# CapableOf	kids	play_soccer	1.0
# CapableOf	kids	play_soccer_in_school	1.0
# CapableOf	people	play_soccer_in_back_yard	1.0
# CapableOf	soccer	cause_head_injuries	1.0
# CapableOf	soccer_field_where_children	play_soccer	1.0
# CapableOf	soccer_games_in_uk	attract_violent_people	1.0
# CapableOf	soccer_player	head_ball	1.0
# CapableOf	soccer_player	score_goal	1.0
# CapableOf	soccer_players	head_ball	1.0
# CapableOf	soccer_players	win_matches	1.0
# Causes	playing_soccer	aching_legs	1.0
# Causes	playing_soccer	anger	2.0
# Causes	playing_soccer	becoming_more_skilled_at_soccer	1.0
# Causes	playing_soccer	being_injured	1.0
# Causes	playing_soccer	excitement	1.0
# Causes	playing_soccer	fatigue	1.0
# Causes	playing_soccer	fights	1.0
# Causes	playing_soccer	gaining_recognition	1.0
# Causes	playing_soccer	get_great_exercise	1.0
# Causes	playing_soccer	get_tiered	1.0
# Causes	playing_soccer	getting_tired	2.0
# Causes	playing_soccer	improvement_in_health	1.0
# Causes	playing_soccer	injuries	1.0
# Causes	playing_soccer	injuring_knee	1.0
# Causes	playing_soccer	injury	2.0
# Causes	playing_soccer	knee_injuries	1.0
# Causes	playing_soccer	knee_injury	1.0
# Causes	playing_soccer	leg_injury	1.0
# Causes	playing_soccer	may_win_game	1.0
# Causes	playing_soccer	minor_injury	1.0
# Causes	playing_soccer	one_may_injured	1.0
# Causes	playing_soccer	pleasure_and_maybe_exhaustion	1.0
# Causes	playing_soccer	providing_spectator_sport	1.0
# Causes	playing_soccer	pulled_muscles	1.0
# Causes	playing_soccer	scoring_goal	1.0
# Causes	playing_soccer	sweating	1.0
# Causes	playing_soccer	team_wins	1.0
# Causes	playing_soccer	twisting_knee	1.0
# Causes	playing_soccer	will_get_tired	1.0
# Causes	playing_soccer	will_tired	1.0
# Causes	playing_soccer	winning_game	1.0
# Causes	playing_soccer	working_up_sweat	1.0
# CausesDesire	being_sporty	play_soccer	1.0
# CausesDesire	good_technique	play_soccer	1.0
# CausesDesire	learning_about_soccer	play_soccer	1.0
# CausesDesire	meeting_friends	play_soccer	1.0
# CausesDesire	need_for_exercise	play_soccer	1.0
# CausesDesire	pe_class	play_soccer	1.0
# CausesDesire	seeing_exciting_soccer_game	play_soccer	1.0
# CausesDesire	seeing_great_soccer_team_play	play_soccer	1.0
# CausesDesire	seeing_soccer_game	play_soccer	1.0
# CausesDesire	soccer	have_fun	1.0
# CausesDesire	sunshine	play_soccer	1.0
# CausesDesire	threats_of_death	play_soccer	1.0
# CausesDesire	watching_soccer_match	play_soccer	1.0
# DefinedAs	football	correct_name_for_soccer	1.0
# DefinedAs	one_of_soccer's_moves	header	1.0
# DefinedAs	soccer	favorite_sport_in_brazil	1.0
# DefinedAs	soccer	game_of_football_outside_united_states	1.0
# DefinedAs	soccer	main_sport_of_mexico	1.0
# DefinedAs	soccer_field	place_where_association_football_played	1.0
# DerivedFrom	nonsoccer	soccer	1.0
# DerivedFrom	soccer	assoc	1.0
# DerivedFrom	soccer	assoc	1.0
# DerivedFrom	soccer_football_ball	soccer_football	1.0
# DerivedFrom	soccer_mom	mom	1.0
# DerivedFrom	soccer_mom	soccer	2.0
# DerivedFrom	soccerer	soccer	1.0
# DerivedFrom	soccerist	soccer	1.0
# DerivedFrom	soccerlike	soccer	1.0
# DerivedFrom	soccermania	soccer	1.0
# DerivedFrom	socceroo	kangaroo	1.0
# DerivedFrom	socceroo	soccer	1.0
# DerivedFrom	soccerplex	soccer	1.0
# DerivedFrom	toccer	soccer	1.0
# Desires	friends	play_soccer	1.0
# EtymologicallyRelatedTo	rugger	soccer	0.25
# EtymologicallyRelatedTo	soccer	association_football	0.25
# EtymologicallyRelatedTo	soccer	brekker	0.25
# EtymologicallyRelatedTo	soccer	footer	0.25
# EtymologicallyRelatedTo	soccer	fresher	0.25
# EtymologicallyRelatedTo	soccer	rugby	0.25
# EtymologicallyRelatedTo	soccer	rugger	0.25
# EtymologicallyRelatedTo	soccer	socca	0.25
# EtymologicallyRelatedTo	soccer	socker	0.25
# FormOf	soccer_balls	soccer_ball	1.0
# FormOf	soccer_fields	soccer_field	1.0
# FormOf	soccer_footballs	soccer_football	1.0
# FormOf	soccer_moms	soccer_mom	1.0
# FormOf	soccer_mum	soccer_mom	1.0
# FormOf	soccer_mums	soccer_mum	1.0
# FormOf	soccer_players	soccer_player	1.0
# FormOf	soccerball	soccer_ball	1.0
# FormOf	soccerballs	soccerball	1.0
# FormOf	soccered	soccer	1.0
# FormOf	soccerers	soccerer	1.0
# FormOf	soccering	soccer	1.0
# FormOf	soccerists	soccerist	1.0
# FormOf	socceroos	socceroo	1.0
# FormOf	soccerplexes	soccerplex	1.0
# FormOf	soccers	soccer	1.0
# FormOf	table_soccer	table_football	1.0
# HasA	all_soccer_players	number_on_shirt	1.0
# HasA	hockey_and_soccer_both	goalies	1.0
# HasA	soccer_field	goals_at_opposite_ends	1.0
# HasA	soccer_field	two_goals	1.0
# HasA	soccer_fields	grass	1.0
# HasContext	18_yard_box	soccer	1.0
# HasContext	18_yard_line	soccer	1.0
# HasContext	accy	soccer	1.0
# HasContext	addick	soccer	1.0
# HasContext	advantage	soccer	1.0
# HasContext	air_shot	soccer	1.0
# HasContext	anfield	soccer	1.0
# HasContext	area	soccer	1.0
# HasContext	assist	soccer	1.0
# HasContext	assistant_referee	soccer	1.0
# HasContext	at_double	soccer	1.0
# HasContext	athletic	soccer	1.0
# HasContext	attack	soccer	1.0
# HasContext	attacker	soccer	1.0
# HasContext	attacking_midfielder	soccer	1.0
# HasContext	back_pass	soccer	1.0
# HasContext	backfield	soccer	1.0
# HasContext	backheel	soccer	1.0
# HasContext	backheel	soccer	1.0
# HasContext	baggie	soccer	1.0
# HasContext	baggies	soccer	1.0
# HasContext	ball	soccer	1.0
# HasContext	ball_playing	soccer	1.0
# HasContext	bantam	soccer	1.0
# HasContext	barça	soccer	1.0
# HasContext	beach_soccer	soccer	1.0
# HasContext	bee	soccer	1.0
# HasContext	bfc	soccer	1.0
# HasContext	bicycle_kick	soccer	1.0
# HasContext	black_cat	soccer	1.0
# HasContext	blade	soccer	1.0
# HasContext	blast	soccer	1.0
# HasContext	bluebird	soccer	1.0
# HasContext	bluebirds	soccer	1.0
# HasContext	blues	soccer	1.0
# HasContext	bore_draw	soccer	1.0
# HasContext	boro	soccer	1.0
# HasContext	box	soccer	1.0
# HasContext	box_to_box_midfielder	soccer	1.0
# HasContext	brace	soccer	1.0
# HasContext	break	soccer	1.0
# HasContext	brewer	soccer	1.0
# HasContext	byeline	soccer	1.0
# HasContext	canary	soccer	1.0
# HasContext	cap	soccer	1.0
# HasContext	caution	soccer	1.0
# HasContext	caution	soccer	1.0
# HasContext	ccfc	soccer	1.0
# HasContext	center	soccer	1.0
# HasContext	centre_back	soccer	1.0
# HasContext	centre_circle	soccer	1.0
# HasContext	centre_forward	soccer	1.0
# HasContext	centre_half	soccer	1.0
# HasContext	centreback	soccer	1.0
# HasContext	cfc	soccer	1.0
# HasContext	chairboy	soccer	1.0
# HasContext	champions_league	soccer	1.0
# HasContext	cherry	soccer	1.0
# HasContext	chip_shot	soccer	1.0
# HasContext	christmas_tree_formation	soccer	1.0
# HasContext	city	soccer	1.0
# HasContext	claret	soccer	1.0
# HasContext	clean_sheet	soccer	1.0
# HasContext	clearance	soccer	1.0
# HasContext	clearing	soccer	1.0
# HasContext	concacaf	soccer	1.0
# HasContext	convert	soccer	1.0
# HasContext	corner_kick	soccer	1.0
# HasContext	cottager	soccer	1.0
# HasContext	cottagers	soccer	1.0
# HasContext	cross_shot	soccer	1.0
# HasContext	crossfield	soccer	1.0
# HasContext	cruyff_turn	soccer	1.0
# HasContext	cup_final	soccer	1.0
# HasContext	cup_final	soccer	2.0
# HasContext	cutback	soccer	1.0
# HasContext	dagger	soccer	1.0
# HasContext	defensive_midfielder	soccer	1.0
# HasContext	direct_free_kick	soccer	1.0
# HasContext	dismiss	soccer	1.0
# HasContext	diving_header	soccer	1.0
# HasContext	double	soccer	1.0
# HasContext	drag	soccer	1.0
# HasContext	dribble	soccer	2.0
# HasContext	drive	soccer	1.0
# HasContext	drop_ball	soccer	1.0
# HasContext	el_clásico	soccer	1.0
# HasContext	end_to_end	soccer	1.0
# HasContext	euro	soccer	1.0
# HasContext	europe	soccer	1.0
# HasContext	euros	soccer	1.0
# HasContext	evertonian	soccer	1.0
# HasContext	ewood	soccer	1.0
# HasContext	fa_cup	soccer	1.0
# HasContext	false_nine	soccer	1.0
# HasContext	far_post	soccer	1.0
# HasContext	fcb	soccer	1.0
# HasContext	fcum	soccer	1.0
# HasContext	find_net	soccer	1.0
# HasContext	finisher	soccer	1.0
# HasContext	finishing	soccer	1.0
# HasContext	five_side	soccer	1.0
# HasContext	flank	soccer	1.0
# HasContext	flat_back_four	soccer	1.0
# HasContext	flick_on	soccer	1.0
# HasContext	foot_trap	soccer	1.0
# HasContext	football_player	soccer	1.0
# HasContext	forward	soccer	1.0
# HasContext	forward_line	soccer	1.0
# HasContext	fourth_official	soccer	1.0
# HasContext	fox	soccer	1.0
# HasContext	fox_in_box	soccer	1.0
# HasContext	free_kick	soccer	2.0
# HasContext	front_line	soccer	1.0
# HasContext	full_back	soccer	1.0
# HasContext	fullback	soccer	1.0
# HasContext	ger	soccer	1.0
# HasContext	ghost_goal	soccer	1.0
# HasContext	gill	soccer	1.0
# HasContext	glance	soccer	1.0
# HasContext	glover	soccer	1.0
# HasContext	goal_area	soccer	1.0
# HasContext	goal_kick	soccer	1.0
# HasContext	goal_kick	soccer	2.0
# HasContext	goal_line	soccer	1.0
# HasContext	goalmouth	soccer	2.0
# HasContext	golden_goal	soccer	1.0
# HasContext	guarder	soccer	1.0
# HasContext	gull	soccer	1.0
# HasContext	gulls	soccer	1.0
# HasContext	gunner	soccer	1.0
# HasContext	gunner	soccer	1.0
# HasContext	hack	soccer_and_rugby	1.0
# HasContext	hacking	soccer	1.0
# HasContext	hammer	soccer	1.0
# HasContext	handbags_come_out	soccer	1.0
# HasContext	handball	soccer	1.0
# HasContext	handball	soccer	1.0
# HasContext	hat_trick	soccer	1.0
# HasContext	hatful	soccer	1.0
# HasContext	hatter	soccer	1.0
# HasContext	header	soccer	1.0
# HasContext	header	soccer	2.0
# HasContext	high_challenge	soccer	1.0
# HasContext	highbury	soccer	1.0
# HasContext	hillsborough	soccer	1.0
# HasContext	hitman	soccer	1.0
# HasContext	hold_up_play	soccer	1.0
# HasContext	holding_midfielder	soccer	1.0
# HasContext	home	soccer	1.0
# HasContext	hoof	football_soccer	1.0
# HasContext	hook	soccer	1.0
# HasContext	hoop	soccer	1.0
# HasContext	hornet	soccer	1.0
# HasContext	in_swinger	soccer	1.0
# HasContext	indirect_free_kick	soccer	1.0
# HasContext	insurance_goal	soccer	1.0
# HasContext	international_rules_football	soccer	1.0
# HasContext	juve	soccer	1.0
# HasContext	kick	soccer	1.0
# HasContext	knock	soccer	1.0
# HasContext	knockdown	soccer	1.0
# HasContext	late_tackle	soccer	1.0
# HasContext	latic	soccer	1.0
# HasContext	lb	soccer	1.0
# HasContext	league_cup	soccer	1.0
# HasContext	left_back	soccer	1.0
# HasContext	leg_breaker	soccer	1.0
# HasContext	lino	soccer	1.0
# HasContext	liverpudlian	soccer	1.0
# HasContext	long_corner	soccer	1.0
# HasContext	long_throw	soccer	1.0
# HasContext	magpie	soccer	1.0
# HasContext	man_city	soccer	1.0
# HasContext	man_on	soccer	1.0
# HasContext	man_united	soccer	1.0
# HasContext	marksman	soccer	1.0
# HasContext	midfielder	soccer	1.0
# HasContext	midtable	soccer	1.0
# HasContext	mls	soccer	1.0
# HasContext	molineux	soccer	1.0
# HasContext	mufc	soccer	1.0
# HasContext	near_post	soccer	1.0
# HasContext	net	soccer	2.0
# HasContext	nod	soccer	1.0
# HasContext	non_league	soccer	1.0
# HasContext	normal_time	soccer	1.0
# HasContext	number_nine	soccer	1.0
# HasContext	number_one	soccer	1.0
# HasContext	nutmeg	soccer	1.0
# HasContext	nutmegger	soccer	1.0
# HasContext	o	soccer	1.0
# HasContext	off_side_rule	soccer	1.0
# HasContext	old_firm	soccer	1.0
# HasContext	old_trafford	soccer	1.0
# HasContext	one_time	soccer	1.0
# HasContext	one_timer	soccer	1.0
# HasContext	one_two	soccer	1.0
# HasContext	out_ball	soccer	1.0
# HasContext	outswinging	soccer	1.0
# HasContext	overhead	soccer	1.0
# HasContext	overhead_kick	soccer	1.0
# HasContext	own_goal	soccer	2.0
# HasContext	palace	soccer	1.0
# HasContext	panenka	soccer	1.0
# HasContext	park	soccer	1.0
# HasContext	park_bus	soccer	1.0
# HasContext	pen	soccer	1.0
# HasContext	penalty_box	soccer	1.0
# HasContext	penalty_goal	soccer	1.0
# HasContext	penalty_kick	soccer	1.0
# HasContext	phantom_goal	soccer	1.0
# HasContext	pick_out	soccer	1.0
# HasContext	pick_up	soccer	1.0
# HasContext	piledriver	soccer	1.0
# HasContext	pilgrim	soccer	1.0
# HasContext	pinball	soccer	1.0
# HasContext	pirate	soccer	1.0
# HasContext	place_kick	soccer	2.0
# HasContext	play_in	soccer	1.0
# HasContext	poacher	soccer	1.0
# HasContext	pompey	soccer	1.0
# HasContext	posh	soccer	1.0
# HasContext	potter	soccer	1.0
# HasContext	pull_trigger	soccer	1.0
# HasContext	punt	soccer	1.0
# HasContext	punt	soccer	1.0
# HasContext	put_through	soccer	1.0
# HasContext	rabona	soccer	1.0
# HasContext	ram	soccer	1.0
# HasContext	reaction_save	soccer	1.0
# HasContext	rearguard	soccer	1.0
# HasContext	red_devil	soccer	1.0
# HasContext	release	soccer	1.0
# HasContext	relegate	soccer	1.0
# HasContext	return_pass	soccer	1.0
# HasContext	reverse_pass	soccer	1.0
# HasContext	right_back	soccer	1.0
# HasContext	robin	soccer	1.0
# HasContext	roll	soccer	1.0
# HasContext	route_one_football	soccer	1.0
# HasContext	rover	soccer	1.0
# HasContext	royal	soccer	1.0
# HasContext	run	soccer	1.0
# HasContext	saddler	soccer	1.0
# HasContext	saints	soccer	1.0
# HasContext	scissor_kick	soccer	1.0
# HasContext	scissor_tackle	soccer	1.0
# HasContext	score_draw	soccer	1.0
# HasContext	scorpion_kick	soccer	1.0
# HasContext	scorpion_volley	soccer	1.0
# HasContext	screamer	soccer	1.0
# HasContext	screening	soccer	1.0
# HasContext	screw	soccer	1.0
# HasContext	scummer	soccer	1.0
# HasContext	seagull	soccer	1.0
# HasContext	seal_dribble	soccer	1.0
# HasContext	seasider	soccer	1.0
# HasContext	second_guarder	soccer	1.0
# HasContext	shielding	soccer	1.0
# HasContext	short_corner	soccer	1.0
# HasContext	shot_stopper	soccer	1.0
# HasContext	shrimp	soccer	1.0
# HasContext	shrimper	soccer	1.0
# HasContext	side_netting	soccer	2.0
# HasContext	silver_goal	soccer	1.0
# HasContext	simulation	soccer	1.0
# HasContext	six_pointer	soccer	1.0
# HasContext	six_yard_box	soccer	1.0
# HasContext	skin	soccer	1.0
# HasContext	sky_blue	soccer	1.0
# HasContext	slice	soccer	1.0
# HasContext	slide_tackle	soccer	1.0
# HasContext	slide_tackle	soccer	1.0
# HasContext	slip_in	soccer	1.0
# HasContext	smother	soccer	1.0
# HasContext	snap_shot	soccer	1.0
# HasContext	snapshot	soccer	1.0
# HasContext	soca_warriors	soccer	1.0
# HasContext	soccer	australian_rules_football	1.0
# HasContext	soccer_football	australia	1.0
# HasContext	soccer_football	us	1.0
# HasContext	soccer_mom	us	1.0
# HasContext	soccered	australian_rules_football	1.0
# HasContext	soccerer	proscribed	1.0
# HasContext	soccering	australian_rules_football	1.0
# HasContext	soccerist	proscribed	1.0
# HasContext	socceroo	australia	1.0
# HasContext	soccerplex	us	1.0
# HasContext	soccers	australian_rules_football	1.0
# HasContext	spl	soccer	1.0
# HasContext	spot	soccer	1.0
# HasContext	spur	soccer	1.0
# HasContext	spurs	soccer	1.0
# HasContext	squad	soccer	1.0
# HasContext	square	soccer	1.0
# HasContext	square_ball	soccer	1.0
# HasContext	stamford_bridge	soccer	1.0
# HasContext	starting_berth	soccer	1.0
# HasContext	stepover	soccer	1.0
# HasContext	stopper	soccer	1.0
# HasContext	straight_red_card	soccer	1.0
# HasContext	streaky	soccer	1.0
# HasContext	strike_partner	soccer	1.0
# HasContext	strikeforce	soccer	1.0
# HasContext	striker	soccer	1.0
# HasContext	strikerless	soccer	1.0
# HasContext	super_eagles	soccer	1.0
# HasContext	super_falcons	soccer	1.0
# HasContext	super_sub	soccer	1.0
# HasContext	supplier	soccer	1.0
# HasContext	swan	soccer	1.0
# HasContext	table_soccer	us	1.0
# HasContext	take_game_to	soccer	1.0
# HasContext	tap_in	soccer	1.0
# HasContext	tap_in	soccer	1.0
# HasContext	target_man	soccer	1.0
# HasContext	tartan_army	soccer	1.0
# HasContext	tee_up	soccer	1.0
# HasContext	third_guarder	soccer	1.0
# HasContext	through_ball	soccer	1.0
# HasContext	throw_out	soccer	1.0
# HasContext	thunderbolt	soccer	1.0
# HasContext	tiger	soccer	1.0
# HasContext	tim	soccer	1.0
# HasContext	tip_over	soccer	1.0
# HasContext	toe_poke	soccer	1.0
# HasContext	toe_poke	soccer	1.0
# HasContext	toffee	soccer	1.0
# HasContext	toffeeman	soccer	1.0
# HasContext	toon_army	soccer	1.0
# HasContext	total_football	soccer	1.0
# HasContext	tottenham	soccer	1.0
# HasContext	tractor_boy	soccer	1.0
# HasContext	transfer_window	soccer	1.0
# HasContext	trotter	soccer	1.0
# HasContext	tuck_in	soccer	1.0
# HasContext	turn	soccer	1.0
# HasContext	turn	soccer	1.0
# HasContext	turn_in	soccer	1.0
# HasContext	ultra	soccer	1.0
# HasContext	up_front	soccer	1.0
# HasContext	var	soccer	1.0
# HasContext	video_assistant_referee	soccer	1.0
# HasContext	villa	soccer	1.0
# HasContext	villa_park	soccer	1.0
# HasContext	villan	soccer	1.0
# HasContext	villans	soccer	1.0
# HasContext	wall	soccer	1.0
# HasContext	wanderer	soccer	1.0
# HasContext	wednesdayite	soccer	1.0
# HasContext	whip_in	soccer	1.0
# HasContext	white_hart_lane	soccer	1.0
# HasContext	wing_back	soccer	1.0
# HasContext	wing_play	soccer	1.0
# HasContext	winger	soccer	2.0
# HasContext	wingplay	soccer	1.0
# HasContext	xi	soccer	1.0
# HasContext	ynwa	soccer	1.0
# HasContext	young_lions	soccer	1.0
# HasContext	zone_defense	soccer	1.0
# HasFirstSubevent	play_soccer	flip_coin	1.0
# HasFirstSubevent	play_soccer	get_dressed_properly	1.0
# HasFirstSubevent	play_soccer	jog	1.0
# HasFirstSubevent	play_soccer	join_team	1.0
# HasLastSubevent	play_soccer	congradulate_other_team	1.0
# HasLastSubevent	play_soccer	leave_field	2.0
# HasLastSubevent	play_soccer	put_away_ball	1.0
# HasLastSubevent	play_soccer	shower	1.0
# HasLastSubevent	play_soccer	swap_shirts	1.0
# HasLastSubevent	play_soccer	take_off_shoes	1.0
# HasLastSubevent	play_soccer	walk_off_field	1.0
# HasPrerequisite	play_soccer	equip_yourself	1.0
# HasPrerequisite	play_soccer	find_team	2.0
# HasPrerequisite	play_soccer	form_team	1.0
# HasPrerequisite	play_soccer	gather_team	1.0
# HasPrerequisite	play_soccer	get_ball	1.0
# HasPrerequisite	play_soccer	get_ball_and_friends	1.0
# HasPrerequisite	play_soccer	get_dressed	1.0
# HasPrerequisite	play_soccer	get_soccer_boots	1.0
# HasPrerequisite	play_soccer	go_onto_field	1.0
# HasPrerequisite	play_soccer	go_outdoors	1.0
# HasPrerequisite	play_soccer	go_to_soccer_stadium	1.0
# HasPrerequisite	play_soccer	go_to_stadium	1.0
# HasPrerequisite	play_soccer	good	1.0
# HasPrerequisite	play_soccer	have_ball	1.0
# HasPrerequisite	play_soccer	have_team	1.0
# HasPrerequisite	play_soccer	have_two_goals_on_field	1.0
# HasPrerequisite	play_soccer	in_shape	2.0
# HasPrerequisite	play_soccer	join_soccer_team	2.0
# HasPrerequisite	play_soccer	join_team	4.0
# HasPrerequisite	play_soccer	kick_ball	2.828
# HasPrerequisite	play_soccer	kick_balls	2.828
# HasPrerequisite	play_soccer	learn_soccer	1.0
# HasPrerequisite	play_soccer	learn_to_run	1.0
# HasPrerequisite	play_soccer	leave_house	1.0
# HasPrerequisite	play_soccer	not_use_hand	1.0
# HasPrerequisite	play_soccer	practice	1.0
# HasPrerequisite	play_soccer	practice_kicking_ball	1.0
# HasPrerequisite	play_soccer	put_on_cleats	1.0
# HasPrerequisite	play_soccer	put_on_knee_pads	1.0
# HasPrerequisite	play_soccer	run	1.0
# HasPrerequisite	play_soccer	train_for_ita	1.0
# HasPrerequisite	play_soccer	try_out_for_team	1.0
# HasPrerequisite	playing_soccer	22_people	1.0
# HasPrerequisite	playing_soccer	ball	3.464
# HasPrerequisite	playing_soccer	coordination	1.0
# HasPrerequisite	playing_soccer	endurance	1.0
# HasPrerequisite	playing_soccer	energy	1.0
# HasPrerequisite	playing_soccer	football	1.0
# HasPrerequisite	playing_soccer	good_fitness	1.0
# HasPrerequisite	playing_soccer	gravity	1.0
# HasPrerequisite	playing_soccer	like_soccer	1.0
# HasPrerequisite	playing_soccer	place_to_play	1.0
# HasPrerequisite	playing_soccer	players	1.0
# HasPrerequisite	playing_soccer	skill	1.0
# HasPrerequisite	playing_soccer	swift_movements	1.0
# HasPrerequisite	release_energy	play_soccer	1.0
# HasProperty	dribbling	important_in_soccer_and_basketball	1.0
# HasProperty	heading_soccer_ball	dangerous	1.0
# HasProperty	soccer	competitive	1.0
# HasProperty	soccer	sport	1.0
# HasProperty	soccer_balls	spherical	1.0
# HasProperty	soccer_field	green	1.0
# HasSubevent	play_soccer	break_leg	1.0
# HasSubevent	play_soccer	chase_ball	3.464
# HasSubevent	play_soccer	falling_down	1.0
# HasSubevent	play_soccer	get_fit	1.0
# HasSubevent	play_soccer	get_tired	1.0
# HasSubevent	play_soccer	get_very_bored	1.0
# HasSubevent	play_soccer	goal_scored	1.0
# HasSubevent	play_soccer	kick_football_around	1.0
# HasSubevent	play_soccer	kick_soccer_ball	2.828
# HasSubevent	play_soccer	kicking_soccer_ball	1.0
# HasSubevent	play_soccer	running	1.0
# HasSubevent	play_soccer	score	1.0
# HasSubevent	play_soccer	scoring_goal	1.0
# HasSubevent	playing_soccer	block_shot	1.0
# HasSubevent	playing_soccer	bouncing_ball_on_head	1.0
# HasSubevent	playing_soccer	could_score_goal	4.472
# HasSubevent	playing_soccer	dive	1.0
# HasSubevent	playing_soccer	falling_down	1.0
# HasSubevent	playing_soccer	get_hurt	1.0
# HasSubevent	playing_soccer	getting_injured	1.0
# HasSubevent	playing_soccer	getting_kicked_in_shin	1.0
# HasSubevent	playing_soccer	heading_ball	1.0
# HasSubevent	playing_soccer	heartbeat_becomes_fast	1.0
# HasSubevent	playing_soccer	kick_another_player	1.0
# HasSubevent	playing_soccer	kick_football	1.0
# HasSubevent	playing_soccer	kick_soccer_ball	1.0
# HasSubevent	playing_soccer	score_goal	1.0
# HasSubevent	playing_soccer	score_own_goal	1.0
# HasSubevent	playing_soccer	scoring_goal	1.0
# HasSubevent	playing_soccer	winning	1.0
# IsA	49	soccer_club	0.5
# IsA	adam_smith	soccer_player	0.5
# IsA	aleksandr_prokhorov	soccer_manager	0.5
# IsA	alex	soccer_player	0.5
# IsA	alexis	soccer_player	0.5
# IsA	alexis	soccer_player	0.5
# IsA	american_word_for_football	soccer	1.0
# IsA	anderson	soccer_player	0.5
# IsA	andrew_johnson	soccer_player	0.5
# IsA	australian_football_league	soccer_league	0.5
# IsA	bauer	soccer_manager	0.5
# IsA	beach_soccer	sport	0.5
# IsA	bernard	soccer_player	0.5
# IsA	bruno	soccer_player	0.5
# IsA	bundesliga	soccer_league	0.5
# IsA	bundesliga	soccer_league	0.5
# IsA	capi	soccer_manager	0.5
# IsA	capone	soccer_manager	0.5
# IsA	ceará	soccer_player	0.5
# IsA	chess_and_soccer	both_games	1.0
# IsA	china	soccer_player	0.5
# IsA	chupe	soccer_player	0.5
# IsA	corona	soccer_player	0.5
# IsA	cris	soccer_player	0.5
# IsA	cristiano_ronaldo	soccer_player	0.5
# IsA	daniel_jones	soccer_player	0.5
# IsA	danny	soccer_player	0.5
# IsA	dante	soccer_player	0.5
# IsA	deco	soccer_player	0.5
# IsA	dida	soccer_player	0.5
# IsA	didi	soccer_manager	0.5
# IsA	eredivisie	soccer_league	0.5
# IsA	fernando	soccer_player	0.5
# IsA	fk_sarajevo	soccer_club	0.5
# IsA	football_league	soccer_league	0.5
# IsA	frank_baum	soccer_manager	0.5
# IsA	fred	soccer_player	0.5
# IsA	freddy	soccer_player	0.5
# IsA	gabi	soccer_player	0.5
# IsA	game_of_indoor_soccer	game_event	1.0
# IsA	game_of_indoor_soccer	game_played_in_quarters	1.0
# IsA	game_of_indoor_soccer	team_sports_competition	1.0
# IsA	game_of_professional_soccer	game_event	1.0
# IsA	game_of_professional_soccer	soccer_game	1.0
# IsA	game_of_professional_soccer	team_sports_competition	1.0
# IsA	goalie	soccer_player	1.0
# IsA	goalkeeper	soccer_player	2.0
# IsA	group_of_soccer_players	group_of_people	1.0
# IsA	guga	soccer_player	0.5
# IsA	hans_geiger	soccer_manager	0.5
# IsA	homos	soccer_player	0.5
# IsA	hulk	soccer_player	0.5
# IsA	ibson	soccer_player	0.5
# IsA	ilan	soccer_player	0.5
# IsA	iller	soccer_club	0.5
# IsA	indoor_soccer	sport	0.5
# IsA	indoor_soccer_team	soccer_team	1.0
# IsA	international_soccer_competition	international_competition	1.0
# IsA	international_soccer_competition	team_sports_competition	1.0
# IsA	international_soccer_federation	sports_organization	1.0
# IsA	international_soccer_federation	world_organization	1.0
# IsA	jack_robinson	soccer_player	0.5
# IsA	jack_robinson	soccer_player	0.5
# IsA	james_wilson	soccer_player	0.5
# IsA	jean	soccer_player	0.5
# IsA	juan_carlos	soccer_player	0.5
# IsA	kali	soccer_player	0.5
# IsA	kelly	soccer_player	0.5
# IsA	kike	soccer_player	0.5
# IsA	kiko	soccer_player	0.5
# IsA	lauren	soccer_player	0.5
# IsA	league	soccer_league	0.5
# IsA	lee_ho	soccer_player	0.5
# IsA	ligue_1	soccer_league	0.5
# IsA	ligue_1	soccer_league	0.5
# IsA	lima	soccer_player	0.5
# IsA	lincoln	soccer_player	0.5
# IsA	lionel_messi	soccer_player	0.5
# IsA	love	soccer_player	0.5
# IsA	mancini	soccer_player	0.5
# IsA	mano	soccer_player	0.5
# IsA	marta	soccer_player	0.5
# IsA	maxwell	soccer_player	0.5
# IsA	mikhail	soccer_player	0.5
# IsA	milo	soccer_player	0.5
# IsA	miranda	soccer_player	0.5
# IsA	n.e.c	soccer_club	0.5
# IsA	nacho	soccer_player	0.5
# IsA	nano	soccer_player	0.5
# IsA	national_football_league	soccer_league	0.5
# IsA	national_league	soccer_league	0.5
# IsA	national_league	soccer_league	0.5
# IsA	national_soccer_team	national_team	1.0
# IsA	nui	soccer_club	0.5
# IsA	olympic_soccer_competition	men's_team_sports_event	1.0
# IsA	olympic_soccer_competition	summer_olympics_competition	1.0
# IsA	oscar	soccer_manager	0.5
# IsA	oscar	soccer_player	0.5
# IsA	pedro	soccer_player	0.5
# IsA	people	exposed_when_play_soccer	1.0
# IsA	petit	soccer_manager	0.5
# IsA	pita	soccer_manager	0.5
# IsA	playing_indoor_soccer	intelligent_agent_activity	1.0
# IsA	playing_indoor_soccer	playing_game	1.0
# IsA	playing_indoor_soccer	playing_of_sports_event	1.0
# IsA	playing_professional_soccer	playing_association_football	1.0
# IsA	playing_professional_soccer	playing_game	1.0
# IsA	playing_professional_soccer	playing_of_sports_event	1.0
# IsA	premier_league	soccer_league	0.5
# IsA	primeira_liga	soccer_league	0.5
# IsA	qi	soccer_player	0.5
# IsA	quim	soccer_player	0.5
# IsA	rafa	soccer_player	0.5
# IsA	rap	soccer_club	0.5
# IsA	recio	soccer_player	0.5
# IsA	ricardo	soccer_manager	0.5
# IsA	ricardo	soccer_player	0.5
# IsA	richard_wright	soccer_player	0.5
# IsA	rincón	soccer_player	0.5
# IsA	robert_koch	soccer_player	0.5
# IsA	ronaldo	soccer_player	0.5
# IsA	rops	soccer_club	0.5
# IsA	saar	soccer_league	0.5
# IsA	schumacher	soccer_player	0.5
# IsA	serie	soccer_league	0.5
# IsA	serie	soccer_league	0.5
# IsA	serie_b	soccer_league	0.5
# IsA	silas	soccer_player	0.5
# IsA	soccer	fun	2.0
# IsA	soccer	game	2.828
# IsA	soccer	passtime	1.0
# IsA	soccer	popular_outdoor_game	1.0
# IsA	soccer	popular_school_sport	1.0
# IsA	soccer	popular_sport_in_greece	1.0
# IsA	soccer	rough_game	1.0
# IsA	soccer	sport	9.165
# IsA	soccer	team_sport	3.464
# IsA	soccer	football	2.0
# IsA	soccer_accessory	artifact	1.0
# IsA	soccer_and_rugby	sports	1.0
# IsA	soccer_ball	ball	2.828
# IsA	soccer_ball	ball	2.0
# IsA	soccer_cleat	cleat	1.0
# IsA	soccer_coach	coach	1.0
# IsA	soccer_field	playing_field	1.0
# IsA	soccer_field	playing_field	2.0
# IsA	soccer_game	game_event	1.0
# IsA	soccer_game	team_sports_competition	1.0
# IsA	soccer_goal	goal	1.0
# IsA	soccer_league	group_of_sports_teams	1.0
# IsA	soccer_player	athlete	1.0
# IsA	soccer_player	worker	1.0
# IsA	soccer_player	athlete	2.0
# IsA	soccer_player	player	2.0
# IsA	soccer_shoe	athletic_footwear	1.0
# IsA	soccer_team	sports_team	1.0
# IsA	soccer_team	sports_team	1.0
# IsA	strongest	soccer_club	0.5
# IsA	süper_lig	soccer_league	0.5
# IsA	teck	soccer_club	0.5
# IsA	tinga	soccer_player	0.5
# IsA	video_soccer_game	computer_game	1.0
# IsA	video_soccer_game	computer_game_program_sports	1.0
# IsA	viola	soccer_player	0.5
# IsA	voro	soccer_manager	0.5
# IsA	washington	soccer_player	0.5
# MadeOf	soccer_ball	leather	2.0
# MotivatedByGoal	hear_crowd_go_mad	goal_in_soccer_was_made	1.0
# MotivatedByGoal	play_soccer	beat_other_team	1.0
# MotivatedByGoal	play_soccer	earn_money_with	1.0
# MotivatedByGoal	play_soccer	enjoy_outdoor_sports	1.0
# MotivatedByGoal	play_soccer	enjoy_sport	2.0
# MotivatedByGoal	play_soccer	enjoy_sports	2.0
# MotivatedByGoal	play_soccer	exersize_and_to_play_game	1.0
# MotivatedByGoal	play_soccer	fun	1.0
# MotivatedByGoal	play_soccer	have_fun	2.828
# MotivatedByGoal	play_soccer	it's_fun_sport	1.0
# MotivatedByGoal	play_soccer	keep_fit	1.0
# MotivatedByGoal	play_soccer	kick_ball	1.0
# MotivatedByGoal	play_soccer	kick_balls	1.0
# MotivatedByGoal	play_soccer	please_mother	1.0
# MotivatedByGoal	play_soccer	run_alot	1.0
# MotivatedByGoal	play_soccer	run_hard	1.0
# MotivatedByGoal	play_soccer	soccer_fun	1.0
# MotivatedByGoal	play_soccer	sports_healthful	1.0
# MotivatedByGoal	play_soccer	victory	2.0
# MotivatedByGoal	play_soccer	wear_shorts	1.0
# MotivatedByGoal	play_soccer	win	1.0
# NotHasProperty	soccer	very_popular_in_usa	1.0
# PartOf	headshot	soccer	2.0
# ReceivesAction	soccer	played	2.0
# ReceivesAction	soccer	played_on_field_of_grass	1.0
# ReceivesAction	soccer	played_on_soccer_field	1.0
# ReceivesAction	soccer	played_through_series_of_games	1.0
# ReceivesAction	soccer	played_with_balls	1.0
# ReceivesAction	soccer_ball	made_up_of_pentagons_and_hexagons	1.0
# ReceivesAction	soccer_ball	purchased_from_sports_equipment_store	2.0
# ReceivesAction	soccer_field	covered_with_grass	1.0
# ReceivesAction	soccer_field_where_soccer	played	1.0
# ReceivesAction	where_soccer	played	1.0
# RelatedTo	aftertouch	soccer	1.0
# RelatedTo	all_whites	soccer	1.0
# RelatedTo	american_football	soccer	1.0
# RelatedTo	attacker	soccer	1.0
# RelatedTo	bafana_bafana	soccer	1.0
# RelatedTo	ball	basket_soccer	0.214
# RelatedTo	ball	in_soccer	0.105
# RelatedTo	ball	soccer	2.181
# RelatedTo	ball	soccer_base	0.277
# RelatedTo	ball	soccer_thing	0.161
# RelatedTo	ballet_dad	soccer_mom	1.0
# RelatedTo	beach_soccer	sand	1.0
# RelatedTo	beach_soccer	soccer	1.0
# RelatedTo	beautiful_game	soccer	1.0
# RelatedTo	blow_football	soccer	1.0
# RelatedTo	cherry_pick	soccer	1.0
# RelatedTo	cleat	soccer	0.26
# RelatedTo	cleat	soccer_shoe	0.26
# RelatedTo	club	soccer	0.22
# RelatedTo	club	soccer_team	0.22
# RelatedTo	dugout	soccer	1.0
# RelatedTo	early_bath	soccer	1.0
# RelatedTo	field	soccer	0.521
# RelatedTo	field	soccer_space	0.152
# RelatedTo	five_side	soccer	1.0
# RelatedTo	flop	soccer	1.0
# RelatedTo	foosball	table_soccer	1.0
# RelatedTo	football	american_soccer	0.172
# RelatedTo	football	europe_soccer	0.171
# RelatedTo	football	soccer	0.343
# RelatedTo	football	soccer	1.0
# RelatedTo	football_hooligan	soccer	1.0
# RelatedTo	football_hooliganism	soccer	1.0
# RelatedTo	football_player	soccer	1.0
# RelatedTo	footer	soccer	1.0
# RelatedTo	footy	soccer	1.0
# RelatedTo	forward	soccer	1.0
# RelatedTo	futsal	soccer	1.0
# RelatedTo	game	or_soccer	0.196
# RelatedTo	game	soccer	0.196
# RelatedTo	goal	soccer	2.063
# RelatedTo	goal	soccer_field	0.219
# RelatedTo	goal	soccer_score	0.795
# RelatedTo	goal	soccer_touchdown	0.105
# RelatedTo	goal	soccer_win	0.146
# RelatedTo	goal_post	soccer	1.0
# RelatedTo	gridiron_football	soccer_football	1.0
# RelatedTo	ground	soccer	1.0
# RelatedTo	hockey_mom	soccer_mom	1.0
# RelatedTo	juke	soccer	1.0
# RelatedTo	keepie_uppie	soccer_ball	1.0
# RelatedTo	kick	in_soccer	0.179
# RelatedTo	kick	soccer	0.876
# RelatedTo	kick	soccer_action	0.17
# RelatedTo	kickabout	soccer	1.0
# RelatedTo	kickaround	soccer	1.0
# RelatedTo	mls	soccer	1.0
# RelatedTo	motoball	soccer	1.0
# RelatedTo	net	soccer	1.0
# RelatedTo	nonsoccer	soccer	1.0
# RelatedTo	north_american_football	soccer_football	1.0
# RelatedTo	olyroos	soccer	1.0
# RelatedTo	outshoot	soccer	1.0
# RelatedTo	pitch	soccer	1.0
# RelatedTo	power_play	soccer	1.0
# RelatedTo	rugger	soccer	1.0
# RelatedTo	scrimmage	soccer	1.0
# RelatedTo	seal_dribble	soccer	1.0
# RelatedTo	soccer	american	0.126
# RelatedTo	soccer	ball	1.271
# RelatedTo	soccer	ball_game	0.102
# RelatedTo	soccer	ball_goal	0.102
# RelatedTo	soccer	ball_kicking	0.142
# RelatedTo	soccer	ball_players	0.262
# RelatedTo	soccer	balls	0.265
# RelatedTo	soccer	english	0.326
# RelatedTo	soccer	english_ball	0.102
# RelatedTo	soccer	english_football	0.224
# RelatedTo	soccer	europe	0.383
# RelatedTo	soccer	europe_football	0.171
# RelatedTo	soccer	europe_game	0.171
# RelatedTo	soccer	foot	0.146
# RelatedTo	soccer	foot_ball	0.146
# RelatedTo	soccer	football	1.484
# RelatedTo	soccer	fun	0.19
# RelatedTo	soccer	game	0.857
# RelatedTo	soccer	goal	0.102
# RelatedTo	soccer	kicking	0.295
# RelatedTo	soccer	players	0.262
# RelatedTo	soccer	spanish	0.219
# RelatedTo	soccer	spanish_football	0.219
# RelatedTo	soccer	sport	0.836
# RelatedTo	soccer	summer	0.106
# RelatedTo	soccer	association_football	1.0
# RelatedTo	soccer	rugger	1.0
# RelatedTo	soccer	football	1.0
# RelatedTo	soccer_ball	football	1.0
# RelatedTo	soccer_ball	soccer	1.0
# RelatedTo	soccer_field	playing_field	1.0
# RelatedTo	soccer_field	soccer	1.0
# RelatedTo	soccer_football	american_football	1.0
# RelatedTo	soccer_football	association_football	1.0
# RelatedTo	soccer_football	australian_rules_football	1.0
# RelatedTo	soccer_football	canadian_football	1.0
# RelatedTo	soccer_football	football	1.0
# RelatedTo	soccer_football	gaelic_football	1.0
# RelatedTo	soccer_football	gridiron_football	1.0
# RelatedTo	soccer_football	international_football	1.0
# RelatedTo	soccer_football	irish_football	1.0
# RelatedTo	soccer_football	north_american_football	1.0
# RelatedTo	soccer_football	rugby_football	1.0
# RelatedTo	soccer_football	soccer	1.0
# RelatedTo	soccer_mom	activities	1.0
# RelatedTo	soccer_mom	age	1.0
# RelatedTo	soccer_mom	appendix:american_dialect_society_words_of_year	1.0
# RelatedTo	soccer_mom	ballet_dad	1.0
# RelatedTo	soccer_mom	children	1.0
# RelatedTo	soccer_mom	hockey_mom	1.0
# RelatedTo	soccer_mom	school	1.0
# RelatedTo	soccer_mom	sporting	1.0
# RelatedTo	soccer_mom	transport	1.0
# RelatedTo	soccer_mom	woman	1.0
# RelatedTo	soccer_mom	women	1.0
# RelatedTo	soccer_player	soccer	1.0
# RelatedTo	soccerballs	soccerball	1.0
# RelatedTo	soccerer	soccer_player	1.0
# RelatedTo	soccerist	player	1.0
# RelatedTo	soccerist	soccer	1.0
# RelatedTo	soccerlike	soccer	1.0
# RelatedTo	soccermania	soccer	1.0
# RelatedTo	socceroo	soccer	1.0
# RelatedTo	socceroo	socceroos	1.0
# RelatedTo	socceroos	association_football	1.0
# RelatedTo	socceroos	australia	1.0
# RelatedTo	socceroos	man	1.0
# RelatedTo	socceroos	national	1.0
# RelatedTo	socceroos	representative	1.0
# RelatedTo	socceroos	soccer	1.0
# RelatedTo	socceroos	socceroo	1.0
# RelatedTo	socceroos	team	1.0
# RelatedTo	soccerplex	complex	1.0
# RelatedTo	soccerplex	soccer	1.0
# RelatedTo	soccerplex	sport	1.0
# RelatedTo	stage_mom	soccer_mom	1.0
# RelatedTo	step_over	soccer	1.0
# RelatedTo	striker	soccer	1.0
# RelatedTo	table_football	soccer	1.0
# RelatedTo	total_football	soccer	1.0
# RelatedTo	transfer_window	soccer	1.0
# RelatedTo	waitress_mom	soccer_mom	1.0
# RelatedTo	wanderer	soccer	1.0
# RelatedTo	wogball	soccer	1.0
# Synonym	association_football	soccer	2.0
# Synonym	beach_soccer	beach_soccer	0.5
# Synonym	beach_soccer	beach_football	1.0
# Synonym	football	soccer	2.0
# Synonym	football	soccerball	1.0
# Synonym	football_pitch	soccer_field	1.0
# Synonym	futsal	indoor_soccer	2.0
# Synonym	indoor_soccer	indoor_soccer	0.5
# Synonym	pitch	soccer_field	2.0
# Synonym	soccer	association_football	1.0
# Synonym	soccer	football	2.0
# Synonym	soccer	soccer_football	1.0
# Synonym	soccer_field	football_pitch	1.0
# Synonym	soccer_football	soccer_football_ball	1.0
# Synonym	soccer_player	footballer	1.0
# Synonym	soccerist	footballer	1.0
# Synonym	table_football	table_soccer	1.0
# Synonym	wogball	soccer	1.0
# UsedFor	amphitheatre	playing_soccer	1.0
# UsedFor	ball	playing_soccer	1.0
# UsedFor	book	learning_about_soccer	1.0
# UsedFor	foot	applying_pressure_to_soccer_ball	1.0
# UsedFor	leg	kicking_soccer_ball	1.0
# UsedFor	person's_head	hit_soccer_ball	1.0
# UsedFor	playing_soccer	being_popular_with_others	1.0
# UsedFor	playing_soccer	children	1.0
# UsedFor	playing_soccer	competition	1.0
# UsedFor	playing_soccer	enjoying_working_in_team	1.0
# UsedFor	playing_soccer	exercise	1.0
# UsedFor	playing_soccer	gaining_fun	1.0
# UsedFor	playing_soccer	kids_in_school	1.0
# UsedFor	playing_soccer	little_girls	1.0
# UsedFor	playing_soccer	physical_fitness	1.0
# UsedFor	playing_soccer	professional_athletes	1.0
# UsedFor	playing_soccer	satisfying_ambition	1.0
# UsedFor	playing_soccer	sport	1.0
# UsedFor	playing_soccer	staying_fit	1.0
# UsedFor	playing_soccer	strengthening_legs	1.0
# UsedFor	playing_soccer	teams	1.0
# UsedFor	pub	watching_football_or_soccer	1.0
# UsedFor	soccer_field	competitive_sport	1.0
# UsedFor	soccer_field	dads_to_watch_kids_play	1.0
# UsedFor	soccer_field	moms_to_take_kids_for_exercise	1.0
# UsedFor	soccer_field	play_game_of_soccer	2.0
# UsedFor	soccer_field	play_soccer	4.472
# UsedFor	soccer_field	play_soccer_on	2.0
# UsedFor	soccer_field	play_sport	1.0
# UsedFor	soccer_field	playing_soccer	1.0
# UsedFor	soccer_field	run_and_play	1.0
# UsedFor	soccerball	playing_soccer	1.0
# UsedFor	sports_ball	playing_soccer	1.0

# %% [markdown]
# ## processing cpnet file and building a nx graph + rel & concept vocabularies

# %%
from tqdm import tqdm 
import networkx as nx

relations = {}
concepts = {}
cpnet_graph = nx.DiGraph()

with open('./data/conceptnet-en.csv', 'r') as f:
    lines = f.readlines()
    for line in tqdm(lines):
        rel, c1, c2, w = line.strip().split('\t')
        rev_rel = f"{rel}_reverse"
        
        if rel not in relations:
            relations[rel] = f"REL_{len(relations)}"
        if rev_rel not in relations:
            relations[rev_rel] = f"REL_{len(relations)}"
        if c1 not in concepts:
            concepts[c1] = f"CSPT_{len(concepts)}"
        if c2 not in concepts:
            concepts[c2] = f"CSPT_{len(concepts)}"
        
        cpnet_graph.add_edge(concepts[c1], concepts[c2], weight=float(w), rel_type=relations[rel])
        cpnet_graph.add_edge(concepts[c2], concepts[c1], weight=float(w), rel_type=relations[rev_rel])
# Out:
# 100%|██████████| 3423004/3423004 [00:24<00:00, 141364.29it/s]

# %%
inv_rels = {v:k for k,v in relations.items()}
inv_concepts = {v:k for k,v in concepts.items()}

# %%
list(set(relations.keys()))[:5], len(relations.keys())
# Out:
# (['capital', 'MadeOf', 'language', 'Entails_reverse', 'CreatedBy_reverse'], 94)

# %% [markdown]
# ## find shortest path between two concepts

# %%
assert 'highway' in concepts
assert 'atlas' in concepts


def print_readable_all_path(graph, src, target):
    src_repr = concepts[src]
    target_repr = concepts[target]
    results = nx.all_simple_paths(graph, src_repr, target_repr, cutoff=2)
    
    for res in results:
        steps = []
        steps.append(src)
        prev_c = src_repr
        for c in res:
            if c == prev_c:
                continue
            cur_rel = graph.edges[prev_c, c]
            steps.append(f"--{inv_rels[cur_rel['rel_type']]}({cur_rel['weight']})-->")
            steps.append(inv_concepts[c])
            prev_c = c
        print(' '.join(steps))
        

def print_readable_shortest_path(graph, src, target):
    steps = []
    src_repr = concepts[src]
    target_repr = concepts[target]
    res = nx.shortest_path(graph, src_repr, target_repr)
    steps.append(src)
    prev_c = src_repr
    for c in res:
        if c == prev_c:
            continue
        cur_rel = graph.edges[prev_c, c]
        steps.append(f"--{inv_rels[cur_rel['rel_type']]}({cur_rel['weight']})-->")
        steps.append(inv_concepts[c])
        prev_c = c
    return ' '.join(steps)
        

#print_readable_shortest_path(cpnet_graph, 'people', 'populated_areas')
# print_readable_all_path(cpnet_graph, 'forest', 'natural_habitat')
print_readable_all_path(cpnet_graph, 'fox', 'city')
# Out:
# fox --AtLocation(1.0)--> back_yard --AtLocation(1.0)--> city
# fox --AtLocation(1.0)--> bar --RelatedTo(0.27)--> city
# fox --AtLocation(1.0)--> book --IsA_reverse(0.5)--> city
# fox --AtLocation(1.0)--> nature --DistinctFrom(0.173)--> city
# fox --AtLocation(1.0)--> new_york --RelatedTo(1.0)--> city
# fox --AtLocation(1.0)--> warren --RelatedTo(1.0)--> city
# fox --HasContext(1.0)--> soccer --HasContext_reverse(1.0)--> city
# fox --RelatedTo(0.323)--> forest --Antonym_reverse(0.23)--> city
# fox --RelatedTo(0.135)--> house --AtLocation(2.0)--> city
# fox --RelatedTo(0.146)--> houses --RelatedTo_reverse(0.428)--> city
# fox --RelatedTo(0.62)--> small --Antonym_reverse(0.14)--> city
# fox --RelatedTo(0.263)--> small_dog --AtLocation(2.0)--> city
# fox --RelatedTo(0.122)--> smaller --RelatedTo_reverse(0.171)--> city
# fox --language(0.5)--> english_language --language_reverse(0.5)--> city

# %%
cpnet_graph.edges['CSPT_1', 'CSPT_5']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /scratch/11812372/ipykernel_48515/63372463.py in <module>
# ----> 1 cpnet_graph.edges['CSPT_1', 'CSPT_5']
#
# /projects/academic/kjoseph/navid/anaconda3/envs/py38/lib/python3.8/site-packages/networkx/classes/reportviews.py in __getitem__(self, e)
#    1030             )
#    1031         u, v = e
# -> 1032         return self._adjdict[u][v]
#    1033
#    1034     # EdgeDataView methods
#
# KeyError: 'CSPT_5'

# %%
cpnet_graph['CSPT_1']
# Out:
# AtlasView({'CSPT_0': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_32059': {'weight': 1.0, 'rel_type': 'REL_4'}, 'CSPT_73566': {'weight': 1.0, 'rel_type': 'REL_15'}, 'CSPT_180550': {'weight': 1.0, 'rel_type': 'REL_15'}, 'CSPT_10340': {'weight': 0.25, 'rel_type': 'REL_25'}, 'CSPT_378685': {'weight': 2.0, 'rel_type': 'REL_26'}, 'CSPT_378686': {'weight': 1.0, 'rel_type': 'REL_26'}, 'CSPT_378784': {'weight': 1.0, 'rel_type': 'REL_27'}, 'CSPT_378815': {'weight': 2.0, 'rel_type': 'REL_27'}, 'CSPT_2729': {'weight': 1.0, 'rel_type': 'REL_30'}, 'CSPT_814875': {'weight': 1.0, 'rel_type': 'REL_30'}, 'CSPT_10488': {'weight': 1.0, 'rel_type': 'REL_30'}, 'CSPT_245458': {'weight': 1.0, 'rel_type': 'REL_30'}, 'CSPT_14931': {'weight': 1.0, 'rel_type': 'REL_30'}, 'CSPT_8750': {'weight': 1.0, 'rel_type': 'REL_30'}, 'CSPT_19734': {'weight': 1.0, 'rel_type': 'REL_30'}, 'CSPT_18071': {'weight': 1.0, 'rel_type': 'REL_30'}, 'CSPT_1053': {'weight': 1.0, 'rel_type': 'REL_71'}, 'CSPT_867809': {'weight': 1.0, 'rel_type': 'REL_38'}, 'CSPT_868167': {'weight': 1.0, 'rel_type': 'REL_39'}, 'CSPT_160444': {'weight': 0.5, 'rel_type': 'REL_42'}, 'CSPT_888946': {'weight': 2.0, 'rel_type': 'REL_44'}, 'CSPT_888947': {'weight': 1.0, 'rel_type': 'REL_44'}, 'CSPT_609': {'weight': 1.0, 'rel_type': 'REL_64'}, 'CSPT_888930': {'weight': 1.0, 'rel_type': 'REL_44'}, 'CSPT_14890': {'weight': 0.5, 'rel_type': 'REL_44'}, 'CSPT_78821': {'weight': 1.0, 'rel_type': 'REL_64'}, 'CSPT_5567': {'weight': 1.0, 'rel_type': 'REL_64'}, 'CSPT_314805': {'weight': 1.0, 'rel_type': 'REL_64'}, 'CSPT_73647': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_89511': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_2361': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_365115': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_417087': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_107577': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_129000': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_597147': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_841539': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_842581': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_289269': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_1953': {'weight': 1.0, 'rel_type': 'REL_65'}, 'CSPT_3047': {'weight': 2.0, 'rel_type': 'REL_67'}, 'CSPT_1': {'weight': 0.5, 'rel_type': 'REL_71'}, 'CSPT_354781': {'weight': 2.0, 'rel_type': 'REL_71'}, 'CSPT_89672': {'weight': 1.0, 'rel_type': 'REL_71'}, 'CSPT_9118': {'weight': 2.0, 'rel_type': 'REL_71'}, 'CSPT_326367': {'weight': 1.0, 'rel_type': 'REL_71'}, 'CSPT_194455': {'weight': 0.5, 'rel_type': 'REL_78'}})

# %%
cpnet_graph.edges['CSPT_1', 'CSPT_32059']
# Out:
# {'weight': 1.0, 'rel_type': 'REL_4'}

# %%
from datasets import load_dataset

ds = load_dataset('trivia_qa', 'rc.web')

ds
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /scratch/11812372/ipykernel_13225/1150397696.py in <module>
#       1 from datasets import load_dataset
#       2
# ----> 3 ds = load_dataset('trivia_qa', 'rc.web')
#       4
#       5 ds
#
# /projects/academic/kjoseph/navid/anaconda3/envs/py38/lib/python3.8/site-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, **config_kwargs)
#    1744
#    1745     # Download and prepare data
# -> 1746     builder_instance.download_and_prepare(
#    1747         download_config=download_config,
#    1748         download_mode=download_mode,
#
# /projects/academic/kjoseph/navid/anaconda3/envs/py38/lib/python3.8/site-packages/datasets/builder.py in download_and_prepare(self, download_config, download_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, **download_and_prepare_kwargs)
#     648             if is_local:  # if cache dir is local, check for available space
#     649                 if not has_sufficient_disk_space(self.info.size_in_bytes or 0, directory=self._cache_dir_root):
# --> 650                     raise OSError(
#     651                         f"Not enough disk space. Needed: {size_str(self.info.size_in_bytes or 0)} (download: {size_str(self.info.download_size or 0)}, generated: {size_str(self.info.dataset_size or 0)}, post-processed: {size_str(self.info.post_processing_size or 0)})"
#     652                     )
#
# OSError: Not enough disk space. Needed: 13.48 GiB (download: 2.48 GiB, generated: 11.00 GiB, post-processed: Unknown size)

# %%
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'question', 'question_concept', 'choices', 'answerKey'],
#         num_rows: 9741
#     })
#     validation: Dataset({
#         features: ['id', 'question', 'question_concept', 'choices', 'answerKey'],
#         num_rows: 1221
#     })
#     test: Dataset({
#         features: ['id', 'question', 'question_concept', 'choices', 'answerKey'],
#         num_rows: 1140
#     })
# })
